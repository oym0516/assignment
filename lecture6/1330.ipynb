# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/1330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A,B = map(int,input().split())

if A > B:
    print('>')
elif A < B:
    print('<')
else:
    print('==')
# Out:
# 1 2
# <
