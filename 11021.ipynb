# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/11021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
T = int(input())

for i in range(1,T+1):
    input_line = input().split()
    a = int(input_line[0])
    b = int(input_line[1])
    print("Case #"+str(i)+':',a+b)
# Out:
# 5
# 1 1
# Case #1: 2
# 2 5
# Case #2: 7
# 3 4
# Case #3: 7
# 9 8
# Case #4: 17
# 5 2
# Case #5: 7
