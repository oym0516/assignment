# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/assignment/blob/main/1764.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N, M = map(int, input().split())
n, m = set(), set()
for i in range(N):
    n.add(input())
for i in range(M):
    m.add(input())

group = n&m
g = sorted(group)
print(len(g))
for ch in g:
    print(ch)
