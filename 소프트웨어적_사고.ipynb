# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4%EC%A0%81_%EC%82%AC%EA%B3%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year=int(input())
if(year%400==0)or((year%4==0)and(not(year%100==0))):
  print("%d is a leap year"%year)
else:
  print("%d is not a leap year"%year)
# Out:
# 2026
# 2026 is not a leap year
