# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/assignment/blob/main/%EB%B2%84%EB%B8%94sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[8,4,9,5]
n= len(a)
for i in range(n-1,0,-1):
  for j in range(0,1):
    if a[j]>a[j+1]:
      a[j],a[j+1]=a[j+1],a[j]
      print(a)
# Out:
# [4, 8, 9, 5]
